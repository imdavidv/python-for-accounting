# %% [markdown]
# ## Finding Duplicates

# %% [markdown]
# #### There are times when you will need to review a file for duplicates. Python 'Pandas' has a function that allows you easily select the duplicates for review. You can select them all, the first occurrences or the prior occurrences.

# %%
# First I will import some libararies
import pandas as pd
import numpy as np

# %%
#  Then I will read an excel file as a data frame
df1=pd.read_excel('Sales_Customers.xlsx')

# %%
# Now, let's have a preview of the dataframe
df1.head()
# Out:
#    custid     companyname        contactname          contacttitle  \
# 0       1  Customer NRZBB     Allen, Michael  Sales Representative
# 1       2  Customer MLTDN      Hassall, Mark                 Owner
# 2       3  Customer KBUDE      Strome, David                 Owner
# 3       4  Customer HFBZG  Cunningham, Conor  Sales Representative
# 4       5  Customer HGVLZ  Higginbotham, Tom   Order Administrator
#
#                          address         city region  postalcode  country  \
# 0                Obere Str. 0123       Berlin    NaN       10092  Germany
# 1  Avda. de la Constitución 5678  México D.F.    NaN       10077   Mexico
# 2                Mataderos  7890  México D.F.    NaN       10097   Mexico
# 3               7890 Hanover Sq.       London    NaN       10046       UK
# 4             Berguvsvägen  5678        Luleå    NaN       10112   Sweden
#
#             phone             fax
# 0     030-3456789     030-0123456
# 1    (5) 789-0123    (5) 456-7890
# 2    (5) 123-4567             NaN
# 3  (171) 456-7890  (171) 456-7891
# 4   0921-67 89 01   0921-23 45 67

# %%
# For the purpose of this project, I will grab a sample from the 'Sales_Customers' file 
df2 = df1.sample(n=15)

# %%
# not necessary, but I will preview the sample
df2.head()
# Out:
#     custid     companyname           contactname          contacttitle  \
# 3        4  Customer HFBZG     Cunningham, Conor  Sales Representative
# 36      37  Customer FRXZL  Óskarsson, Jón Harry       Sales Associate
# 87      88  Customer SRQVM               Li, Yan         Sales Manager
# 33      34  Customer IBVRG          Zhang, Frank    Accounting Manager
# 54      55  Customer KZQZT           Wood, Robin  Sales Representative
#
#                  address            city    region  postalcode  country  \
# 3       7890 Hanover Sq.          London       NaN       10046       UK
# 36   9012 Johnstown Road            Cork  Co. Cork       10051  Ireland
# 87  Rua do Mercado, 4567         Resende        SP       10084   Brazil
# 33     Rua do Paço, 7890  Rio de Janeiro        RJ       10076   Brazil
# 54       7890 Bering St.       Anchorage        AK       10050      USA
#
#              phone             fax
# 3   (171) 456-7890  (171) 456-7891
# 36        8901 234       5678 9012
# 87   (14) 234-5678             NaN
# 33   (21) 789-0123   (21) 789-0124
# 54  (907) 555-0115  (907) 555-0128

# %%
# Now I will join to two files
df3=pd.concat([df1, df2], ignore_index=True)

# %%
# Lets get a row count for the original file
df1.shape
# Out:
# (91, 11)

# %%
# And a row count for the sample file
df2.shape
# Out:
# (15, 11)

# %%
# Finally we will compare the row count for the combined files
df3.shape
# Out:
# (106, 11)

# %%
# We will add the two counts for confirmation
91 + 15
# Out:
# 106

# %%
# Now let's create a seperate data frame to look at the duplicates
dupes=df3.loc[df3.duplicated(keep=False), :]

# %%
# Now I will sort the duplicated data by the column 'custid'
dupes.sort_values('custid')
# Out:
#      custid     companyname           contactname  \
# 0         1  Customer NRZBB        Allen, Michael
# 102       1  Customer NRZBB        Allen, Michael
# 3         4  Customer HFBZG     Cunningham, Conor
# 91        4  Customer HFBZG     Cunningham, Conor
# 105       5  Customer HGVLZ     Higginbotham, Tom
# 4         5  Customer HGVLZ     Higginbotham, Tom
# 10       11  Customer UBHAU          Jaffe, David
# 103      11  Customer UBHAU          Jaffe, David
# 13       14  Customer WNMAF        Jelitto, Jacek
# 104      14  Customer WNMAF        Jelitto, Jacek
# 94       34  Customer IBVRG          Zhang, Frank
# 33       34  Customer IBVRG          Zhang, Frank
# 35       36  Customer LVJSO         Smith, Denise
# 97       36  Customer LVJSO         Smith, Denise
# 92       37  Customer FRXZL  Óskarsson, Jón Harry
# 36       37  Customer FRXZL  Óskarsson, Jón Harry
# 41       42  Customer IAIJK             Zaki, Amr
# 99       42  Customer IAIJK             Zaki, Amr
# 51       52  Customer PZNLA      Natarajan, Mrina
# 101      52  Customer PZNLA      Natarajan, Mrina
# 54       55  Customer KZQZT           Wood, Robin
# 95       55  Customer KZQZT           Wood, Robin
# 98       65  Customer NYUHS        Moore, Michael
# 64       65  Customer NYUHS        Moore, Michael
# 78       79  Customer FAPSM          Wickham, Jim
# 96       79  Customer FAPSM          Wickham, Jim
# 93       88  Customer SRQVM               Li, Yan
# 87       88  Customer SRQVM               Li, Yan
# 100      90  Customer XBBVR     Larsson, Katarina
# 89       90  Customer XBBVR     Larsson, Katarina
#
#                        contacttitle                          address  \
# 0              Sales Representative                  Obere Str. 0123
# 102            Sales Representative                  Obere Str. 0123
# 3              Sales Representative                 7890 Hanover Sq.
# 91             Sales Representative                 7890 Hanover Sq.
# 105             Order Administrator               Berguvsvägen  5678
# 4               Order Administrator               Berguvsvägen  5678
# 10             Sales Representative           Fauntleroy Circus 4567
# 103            Sales Representative           Fauntleroy Circus 4567
# 13                            Owner                   Hauptstr. 0123
# 104                           Owner                   Hauptstr. 0123
# 94               Accounting Manager                Rua do Paço, 7890
# 33               Accounting Manager                Rua do Paço, 7890
# 35             Sales Representative  City Center Plaza 2345 Main St.
# 97             Sales Representative  City Center Plaza 2345 Main St.
# 92                  Sales Associate              9012 Johnstown Road
# 36                  Sales Associate              9012 Johnstown Road
# 41              Marketing Assistant                     2345 Oak St.
# 99              Marketing Assistant                     2345 Oak St.
# 51              Marketing Assistant                    Heerstr. 4567
# 101             Marketing Assistant                    Heerstr. 4567
# 54             Sales Representative                  7890 Bering St.
# 95             Sales Representative                  7890 Bering St.
# 98   Assistant Sales Representative                  6789 Milton Dr.
# 64   Assistant Sales Representative                  6789 Milton Dr.
# 78                Marketing Manager                  Luisenstr. 0123
# 96                Marketing Manager                  Luisenstr. 0123
# 93                    Sales Manager             Rua do Mercado, 4567
# 87                    Sales Manager             Rua do Mercado, 4567
# 100       Owner/Marketing Assistant                  Keskuskatu 2345
# 89        Owner/Marketing Assistant                  Keskuskatu 2345
#
#                city    region  postalcode      country           phone  \
# 0            Berlin       NaN       10092      Germany     030-3456789
# 102          Berlin       NaN       10092      Germany     030-3456789
# 3            London       NaN       10046           UK  (171) 456-7890
# 91           London       NaN       10046           UK  (171) 456-7890
# 105           Luleå       NaN       10112       Sweden   0921-67 89 01
# 4             Luleå       NaN       10112       Sweden   0921-67 89 01
# 10           London       NaN       10064           UK  (171) 789-0123
# 103          London       NaN       10064           UK  (171) 789-0123
# 13             Bern       NaN       10065  Switzerland     0452-678901
# 104            Bern       NaN       10065  Switzerland     0452-678901
# 94   Rio de Janeiro        RJ       10076       Brazil   (21) 789-0123
# 33   Rio de Janeiro        RJ       10076       Brazil   (21) 789-0123
# 35            Elgin        OR       10103          USA  (503) 555-0126
# 97            Elgin        OR       10103          USA  (503) 555-0126
# 92             Cork  Co. Cork       10051      Ireland        8901 234
# 36             Cork  Co. Cork       10051      Ireland        8901 234
# 41        Vancouver        BC       10098       Canada  (604) 567-8901
# 99        Vancouver        BC       10098       Canada  (604) 567-8901
# 51          Leipzig       NaN       10125      Germany      0342-12345
# 101         Leipzig       NaN       10125      Germany      0342-12345
# 54        Anchorage        AK       10050          USA  (907) 555-0115
# 95        Anchorage        AK       10050          USA  (907) 555-0115
# 98      Albuquerque        NM       10109          USA  (505) 555-0125
# 64      Albuquerque        NM       10109          USA  (505) 555-0125
# 78          Münster       NaN       10118      Germany     0251-456789
# 96          Münster       NaN       10118      Germany     0251-456789
# 93          Resende        SP       10084       Brazil   (14) 234-5678
# 87          Resende        SP       10084       Brazil   (14) 234-5678
# 100        Helsinki       NaN       10055      Finland     90-012 3456
# 89         Helsinki       NaN       10055      Finland     90-012 3456
#
#                 fax
# 0       030-0123456
# 102     030-0123456
# 3    (171) 456-7891
# 91   (171) 456-7891
# 105   0921-23 45 67
# 4     0921-23 45 67
# 10              NaN
# 103             NaN
# 13              NaN
# 104             NaN
# 94    (21) 789-0124
# 33    (21) 789-0124
# 35   (503) 555-0135
# 97   (503) 555-0135
# 92        5678 9012
# 36        5678 9012
# 41   (604) 234-5678
# 99   (604) 234-5678
# 51              NaN
# 101             NaN
# 54   (907) 555-0128
# 95   (907) 555-0128
# 98   (505) 555-0134
# 64   (505) 555-0134
# 78      0251-012345
# 96      0251-012345
# 93              NaN
# 87              NaN
# 100     90-789 0123
# 89      90-789 0123
