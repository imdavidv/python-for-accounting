# %% [markdown]
# ## Finding Duplicates

# %%
# First I will import some libararies
import pandas as pd
import numpy as np

# %%
#  Then I will read an excel file as a data frame
df1=pd.read_excel('Sales_Customers.xlsx')

# %%
# Now, let's have a preview of the dataframe
df1.head()
# Out:
#    custid     companyname        contactname          contacttitle  \
# 0       1  Customer NRZBB     Allen, Michael  Sales Representative
# 1       2  Customer MLTDN      Hassall, Mark                 Owner
# 2       3  Customer KBUDE      Strome, David                 Owner
# 3       4  Customer HFBZG  Cunningham, Conor  Sales Representative
# 4       5  Customer HGVLZ  Higginbotham, Tom   Order Administrator
#
#                          address         city region  postalcode  country  \
# 0                Obere Str. 0123       Berlin    NaN       10092  Germany
# 1  Avda. de la Constitución 5678  México D.F.    NaN       10077   Mexico
# 2                Mataderos  7890  México D.F.    NaN       10097   Mexico
# 3               7890 Hanover Sq.       London    NaN       10046       UK
# 4             Berguvsvägen  5678        Luleå    NaN       10112   Sweden
#
#             phone             fax
# 0     030-3456789     030-0123456
# 1    (5) 789-0123    (5) 456-7890
# 2    (5) 123-4567             NaN
# 3  (171) 456-7890  (171) 456-7891
# 4   0921-67 89 01   0921-23 45 67

# %%
# For the purpose of this project, I will grab a sample from the 'Sales_Customers' file 
df2 = df1.sample(n=15)

# %%
# not necessary, but I will preview the sample
df2.head()
# Out:
#     custid     companyname            contactname        contacttitle  \
# 81      82  Customer EYHKM        Veninga, Tjeerd     Sales Associate
# 21      22  Customer DTDMN              Daly, Jim  Accounting Manager
# 48      49  Customer CQRAA         Duerr, Bernard   Marketing Manager
# 28      29  Customer MDLWA  Kolesnikova, Katerina   Marketing Manager
# 69      70  Customer TMXGN        Makovac, Zrinka               Owner
#
#                       address       city region  postalcode country  \
# 81         1234 DaVinci Blvd.   Kirkland     WA       10119     USA
# 21       C/ Moralzarzal, 5678     Madrid    NaN       10080   Spain
# 48  Via Ludovico il Moro 6789    Bergamo    NaN       10106   Italy
# 28   Rambla de Cataluña, 8901  Barcelona    NaN       10081   Spain
# 69   Erling Skakkes gate 2345    Stavern    NaN       10123  Norway
#
#              phone             fax
# 81  (206) 555-0124  (206) 555-0133
# 21  (91) 890 12 34  (91) 567 89 01
# 48      035-345678      035-901234
# 28   (93) 789 0123   (93) 456 7890
# 69     07-89 01 23     07-45 67 89

# %%
# Now I will join to two files
df3=pd.concat([df1, df2], ignore_index=True)

# %%
# Lets get a row count for the original file
df1.shape
# Out:
# (91, 11)

# %%
# And a row count for the sample file
df2.shape
# Out:
# (15, 11)

# %%
# Finally we will compare the row count for the combined files
df3.shape
# Out:
# (106, 11)

# %%
# We will add the two counts for confirmation
91 + 15
# Out:
# 106

# %%
# Now let's create a seperate data frame to look at the duplicates
dupes=df3.loc[df3.duplicated(keep=False), :]

# %%
# Now I will sort the duplicated data by the column 'custid'
dupes.sort_values('custid')
# Out:
#      custid     companyname            contactname          contacttitle  \
# 9        10  Customer EEALV            Culp, Scott    Accounting Manager
# 99       10  Customer EEALV            Culp, Scott    Accounting Manager
# 105      16  Customer GYBBY           Birkby, Dana  Sales Representative
# 15       16  Customer GYBBY           Birkby, Dana  Sales Representative
# 20       21  Customer KIDPX        Russo, Giuseppe   Marketing Assistant
# 104      21  Customer KIDPX        Russo, Giuseppe   Marketing Assistant
# 21       22  Customer DTDMN              Daly, Jim    Accounting Manager
# 92       22  Customer DTDMN              Daly, Jim    Accounting Manager
# 94       29  Customer MDLWA  Kolesnikova, Katerina     Marketing Manager
# 28       29  Customer MDLWA  Kolesnikova, Katerina     Marketing Manager
# 101      31  Customer YJCBX            Orint, Neil       Sales Associate
# 30       31  Customer YJCBX            Orint, Neil       Sales Associate
# 103      42  Customer IAIJK              Zaki, Amr   Marketing Assistant
# 41       42  Customer IAIJK              Zaki, Amr   Marketing Assistant
# 48       49  Customer CQRAA         Duerr, Bernard     Marketing Manager
# 93       49  Customer CQRAA         Duerr, Bernard     Marketing Manager
# 100      53  Customer GCJSG            Mallit, Ken       Sales Associate
# 52       53  Customer GCJSG            Mallit, Ken       Sales Associate
# 98       66  Customer LHANT          Voss, Florian       Sales Associate
# 65       66  Customer LHANT          Voss, Florian       Sales Associate
# 95       70  Customer TMXGN        Makovac, Zrinka                 Owner
# 69       70  Customer TMXGN        Makovac, Zrinka                 Owner
# 81       82  Customer EYHKM        Veninga, Tjeerd       Sales Associate
# 91       82  Customer EYHKM        Veninga, Tjeerd       Sales Associate
# 97       87  Customer ZHYOS        Ludwig, Michael    Accounting Manager
# 86       87  Customer ZHYOS        Ludwig, Michael    Accounting Manager
# 87       88  Customer SRQVM                Li, Yan         Sales Manager
# 96       88  Customer SRQVM                Li, Yan         Sales Manager
# 102      91  Customer CCFIZ             Vasa, Petr                 Owner
# 90       91  Customer CCFIZ             Vasa, Petr                 Owner
#
#                            address           city region  postalcode  country  \
# 9             8901 Tsawassen Blvd.      Tsawassen     BC       10111   Canada
# 99            8901 Tsawassen Blvd.      Tsawassen     BC       10111   Canada
# 105  Berkeley Gardens 0123 Brewery         London    NaN       10039       UK
# 15   Berkeley Gardens 0123 Brewery         London    NaN       10039       UK
# 20                  Rua Orós, 3456      Sao Paulo     SP       10096   Brazil
# 104                 Rua Orós, 3456      Sao Paulo     SP       10096   Brazil
# 21            C/ Moralzarzal, 5678         Madrid    NaN       10080    Spain
# 92            C/ Moralzarzal, 5678         Madrid    NaN       10080    Spain
# 94        Rambla de Cataluña, 8901      Barcelona    NaN       10081    Spain
# 28        Rambla de Cataluña, 8901      Barcelona    NaN       10081    Spain
# 101               Av. Brasil, 5678       Campinas     SP       10128   Brazil
# 30                Av. Brasil, 5678       Campinas     SP       10128   Brazil
# 103                   2345 Oak St.      Vancouver     BC       10098   Canada
# 41                    2345 Oak St.      Vancouver     BC       10098   Canada
# 48       Via Ludovico il Moro 6789        Bergamo    NaN       10106    Italy
# 93       Via Ludovico il Moro 6789        Bergamo    NaN       10106    Italy
# 100  South House 1234 Queensbridge         London    NaN       10061       UK
# 52   South House 1234 Queensbridge         London    NaN       10061       UK
# 98         Strada Provinciale 7890  Reggio Emilia    NaN       10038    Italy
# 65         Strada Provinciale 7890  Reggio Emilia    NaN       10038    Italy
# 95        Erling Skakkes gate 2345        Stavern    NaN       10123   Norway
# 69        Erling Skakkes gate 2345        Stavern    NaN       10123   Norway
# 81              1234 DaVinci Blvd.       Kirkland     WA       10119      USA
# 91              1234 DaVinci Blvd.       Kirkland     WA       10119      USA
# 97                   Torikatu 9012           Oulu    NaN       10045  Finland
# 86                   Torikatu 9012           Oulu    NaN       10045  Finland
# 87            Rua do Mercado, 4567        Resende     SP       10084   Brazil
# 96            Rua do Mercado, 4567        Resende     SP       10084   Brazil
# 102              ul. Filtrowa 6789       Warszawa    NaN       10068   Poland
# 90               ul. Filtrowa 6789       Warszawa    NaN       10068   Poland
#
#               phone             fax
# 9    (604) 901-2345  (604) 678-9012
# 99   (604) 901-2345  (604) 678-9012
# 105  (171) 234-5678  (171) 234-5679
# 15   (171) 234-5678  (171) 234-5679
# 20    (11) 456-7890             NaN
# 104   (11) 456-7890             NaN
# 21   (91) 890 12 34  (91) 567 89 01
# 92   (91) 890 12 34  (91) 567 89 01
# 94    (93) 789 0123   (93) 456 7890
# 28    (93) 789 0123   (93) 456 7890
# 101   (11) 567-8901             NaN
# 30    (11) 567-8901             NaN
# 103  (604) 567-8901  (604) 234-5678
# 41   (604) 567-8901  (604) 234-5678
# 48       035-345678      035-901234
# 93       035-345678      035-901234
# 100  (171) 890-1234  (171) 890-1235
# 52   (171) 890-1234  (171) 890-1235
# 98      0522-012345     0522-678901
# 65      0522-012345     0522-678901
# 95      07-89 01 23     07-45 67 89
# 69      07-89 01 23     07-45 67 89
# 81   (206) 555-0124  (206) 555-0133
# 91   (206) 555-0124  (206) 555-0133
# 97       981-123456      981-789012
# 86       981-123456      981-789012
# 87    (14) 234-5678             NaN
# 96    (14) 234-5678             NaN
# 102   (26) 234-5678   (26) 901-2345
# 90    (26) 234-5678   (26) 901-2345
